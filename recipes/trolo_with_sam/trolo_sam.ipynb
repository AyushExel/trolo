# %% [markdown]
# <img width="838" alt="387845954-73311b13-a624-4736-8472-b22318bcd6b0" src="https://github.com/user-attachments/assets/08091cad-703d-4d7d-84f6-5e6c310bf6c2">
#
#
# # Trolo
# ![pred_0](https://github.com/user-attachments/assets/144ae351-c520-4640-8081-3e9a0db9b432)
#
# A framework for harnessing the power of transformers with YOLO models and other single-shot detectors!
#
# ## Features
#
# - 🔥 Transformer-enhanced object detection
# - 🎯 Single-shot detection capabilities
# - ⚡ High performance inference
# - 🛠️ Easy to use CLI interface
# - 🚀 Fast video stream inference
# - 🧠 Automatic DDP handling

# %% [markdown]
# ## Installation

# %%
# !pip install --upgrade trolo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.2/235.2 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: trolo
#     Found existing installation: trolo 0.1.22
#     Uninstalling trolo-0.1.22:
#       Successfully uninstalled trolo-0.1.22
# ...

# %%
# Displaying PIL images in not supported on Colab

# !trolo predict # run inference visualization on default images

# !trolo predict --input video.mp4 --model dfine-x
# Out:
# 2024-11-30 09:17:43.539526: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-30 09:17:43.570762: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-30 09:17:43.578057: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 09:17:43.592470: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !wget https://github.com/AyushExel/trolo/releases/download/0.1.1/sample.jpg --quiet

# %%
from trolo.inference import DetectionPredictor

predictor = DetectionPredictor("dfine_n.pth")

preds = predictor.predict("sample.jpg") # get prediction dict

visualization = predictor.visualize("sample.jpg") # get visualization

display(visualization[0])
print(preds)
# Out:
# Loading config from checkpoint
# <PIL.Image.Image image mode=RGB size=612x408>
# [{'boxes': tensor([[ 68.1221, 238.0598, 110.5413, 222.4064],
#         [418.5565, 270.1815,  85.1946, 256.6109],
#         [168.4055, 201.5015,  48.5673, 156.4679],
#         [185.1589,  23.3218,  18.9121,  35.4782],
#         [ 17.2192, 147.5157,  33.9145,  32.5515],
#         [234.8656, 203.8223,  49.5121, 152.7102],
#         [302.7029, 216.3118,  56.0266, 192.5858],
#         [ 70.3591, 140.3556,  65.9856,  39.7318],
#         [266.0265, 187.8009,  36.7325, 140.8305]]), 'scores': tensor([0.9011, 0.9314, 0.8392, 0.7802, 0.9127, 0.8447, 0.5731, 0.6214, 0.6343]), 'labels': tensor([0, 0, 0, 9, 2, 0, 0, 2, 0])}]

# %%
# !trolo train --config dfine_n_coco_dummy --batch-size 8
# Out:
# 2024-11-30 09:19:51.679005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-30 09:19:51.717607: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-30 09:19:51.726867: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 09:19:53.325346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# task: detection
# num_workers: 0
# batch_size: None
# resume: None
# tuning: None
# epoches: 1
# last_epoch: -1
# use_amp: True
# use_ema: True
# ema_decay: 0.9999
# ema_warmups: 2000
# sync_bn: True
# clip_max_norm: 0.1
# ...
